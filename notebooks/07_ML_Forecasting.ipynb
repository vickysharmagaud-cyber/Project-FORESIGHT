# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import joblib

# %%
df = pd.read_csv(
    "../data/processed/daily_sales_features.csv",
    parse_dates=["Date"]
)

df.head()
# Out:
# C:\Users\vicky\AppData\Local\Temp\ipykernel_18696\2896824479.py:1: DtypeWarning: Columns (0: StockCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#         Date StockCode  Units_Sold  Revenue  Year  Month  Week  Day  \
# 0 2009-12-11     10002           9     7.65  2009     12    50   11
# 1 2009-12-14     10002          37    32.30  2009     12    51   14
# 2 2009-12-21     10002          12    10.20  2009     12    52   21
# 3 2009-12-22     10002           1     1.70  2009     12    52   22
# 4 2009-12-23     10002           1     0.85  2009     12    52   23
#
#    DayOfWeek  Lag_1  Lag_7  Rolling_7
# 0          4    1.0   12.0  21.714286
# 1          0    9.0    6.0  26.142857
# 2          0   37.0   73.0  17.428571
# 3          1   12.0   49.0  10.571429
# 4          2    1.0    2.0  10.428571

# %%
df.columns
# Out:
# Index(['Date', 'StockCode', 'Units_Sold', 'Revenue', 'Year', 'Month', 'Week',
#        'Day', 'DayOfWeek', 'Lag_1', 'Lag_7', 'Rolling_7'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Date          0
# StockCode     0
# Units_Sold    0
# Revenue       0
# Year          0
# Month         0
# Week          0
# Day           0
# DayOfWeek     0
# Lag_1         0
# Lag_7         0
# Rolling_7     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
features = [
    "Year",
    "Month",
    "Week",
    "Day",
    "DayOfWeek",
    "Lag_1",
    "Lag_7",
    "Rolling_7"
]

X = df[features]

y = df["Units_Sold"]

# %%
split = int(len(df) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

# %%
model = RandomForestRegressor(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, pred)
rmse = np.sqrt(mean_squared_error(y_test, pred))
r2 = r2_score(y_test, pred)

print(f"MAE  : {mae:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 17.89
# RMSE : 68.81
# R²   : 0.3721

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))

plt.plot(
    y_test.values[:200],
    label="Actual"
)

plt.plot(
    pred[:200],
    label="Predicted"
)

plt.title("Demand Forecast")
plt.xlabel("Observations")
plt.ylabel("Units Sold")

plt.legend()

plt.show()

# %%
importance = pd.DataFrame({
    "Feature": features,
    "Importance": model.feature_importances_
})

importance.sort_values(
    "Importance",
    ascending=True
).plot(
    x="Feature",
    y="Importance",
    kind="barh",
    figsize=(8,5),
    legend=False
)

plt.title("Feature Importance")
plt.show()

# %%
joblib.dump(
    model,
    "../models/random_forest_forecast.pkl"
)

print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
df.columns
# Out:
# Index(['Date', 'StockCode', 'Units_Sold', 'Revenue', 'Year', 'Month', 'Week',
#        'Day', 'DayOfWeek', 'Lag_1', 'Lag_7', 'Rolling_7'],
#       dtype='str')

# %%
print(f"MAE  : {mae:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 17.89
# RMSE : 68.81
# R²   : 0.3721
